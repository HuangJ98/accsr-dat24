# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

sns.set_theme(context='notebook')
#https://seaborn.pydata.org/generated/seaborn.set_theme.html

data = {
    'Accent': ['Australia','Canada','Germany','Hong Kong','Irish', 'Indian',"Northern Irish",'New Zealand', 'Filipino', 'Scottish', 'Singapore','England', 'USA','South Africa'],
    'Validation_Loss_FCCN': [0.7232,0.7742,0.4078,0.6864,0.7334,0.5445,0.8501,0.7403,0.6871,0.5851,0.6157,0.7583,0.6332,0.7182],
    'Validation_Loss_xVector': [0.3133,0.3133,0.3133,0.3133,0.3133,0.3133,0.3133,0.3133,0.3133,0.3133,0.3133,0.3133,1.313,0.3133]
}

data1 = {
    'Accent': ['Australia','Canada','Germany','Hong Kong','Irish', 'Indian',"Northern Irish",'New Zealand', 'Filipino', 'Scottish', 'Singapore','England', 'USA','South Africa'],
    'Validation_Loss_FCCN': [0.2035,0.1474,0.1466,0.2347,0.1897,0.2343,0.1672,0.1193,0.1919,0.7067,0.2595,0.1466,0.1428,0.1445],
    'Validation_Loss_xVector': [0.2006,0.147,0.1448,0.2354,0.188,0.2294,0.1627,0.1192,0.1907,0.7311,0.2587,0.1422,0.1424,0.143]
}

df = pd.DataFrame(data)
df1 = pd.DataFrame(data1)

# %%
# Bar Plot for Validation Loss
plt.figure(figsize=(14, 8))
sns.barplot(x='Accent', y='Validation_Loss_FCCN', data=df, label='FCCN')
sns.barplot(x='Accent', y='Validation_Loss_xVector', data=df,  label='xVector', alpha=0.7)
plt.xlabel('Accent')
plt.ylabel('Validation Loss')
plt.title('Validation Loss by Accent for FCCN and xVector')
plt.legend()
plt.xticks(rotation=45)
plt.show()

# %%
data = {
    'Accent': ['Australia','Canada','Germany','Hong Kong','Irish', 'Indian',"Northern Irish",'New Zealand', 'Filipino', 'Scottish', 'Singapore','England', 'USA','Southern Africa'],
    'Validation_Loss_FCCN': [0.7232,0.7742,0.6864,0.7334,0.5445,0.8501,0.7403,0.6871,0.5851,0.6157,0.7583,0.6332,0.7182],
    'Validation_Loss_xVector': [0.3133,0.3133,0.3133,0.3133,0.3133,0.3133,0.3133,0.3133,0.3133,0.3133,0.3133,0.3133,1.313,0.3133]
}

len(data['Accent'])
# Out:
# 14

# %%
plt.figure(figsize=(14, 8))
sns.barplot(x='Accent', y='Validation_Loss_FCCN', data=df1, label='FCCN')
sns.barplot(x='Accent', y='Validation_Loss_xVector', data=df1,  label='xVector', alpha=0.7)
plt.xlabel('Accent')
plt.ylabel('Validation Loss')
plt.title('Validation Loss by Accent for FCCN and xVector')
plt.legend()
plt.xticks(rotation=45)
plt.show()
