# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
exp = "../logs/en/ensemble/train/binary/b7/version_66"
df_train = pd.read_pickle(f"{exp}/dataframes/train.pkl")
df_val = pd.read_pickle(f"{exp}/dataframes/val.pkl")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 exp = "../logs/en/ensemble/train/binary/b7/version_58"
# ----> 2 df_train = pd.read_pickle(f"{exp}/dataframes/train.pkl")
#       3 df_val = pd.read_pickle(f"{exp}/dataframes/val.pkl")
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/pickle.py:185, in read_pickle(filepath_or_buffer, compression, storage_options)
#     123 """
#     124 Load pickled pandas object (or any object) from file.
#     125
#    (...)
#     182 4    4    9
#     183 """
#     184 excs_to_catch = (AttributeError, ImportError, ModuleNotFoundError, TypeError)
# --> 185 with get_handle(
#     186     filepath_or_buffer,
#     187     "rb",
#     188     compression=compression,
#     189     is_text=False,
#     190     storage_options=storage_options,
#     191 ) as handles:
#     192     # 1) try standard library Pickle
# ...

# %%
df_train.columns
# Out:
# Index(['AC Loss', 'events.out.tfevents.1663140137.kyoto.604229.0'], dtype='object')

# %%
df_val.columns
# Out:
# Index(['val_ac_loss - unweighted avg.', 'val_ac_loss per correct accent_us',
#        'Precision_avg', 'val_ac_loss per correct accent_ch',
#        'val_ac_loss per correct accent_it',
#        'val_ac_loss per correct accent_ca', 'Precision_Accented',
#        'F1-score_avg', 'val_ac_loss per correct accent_de_al',
#        'val_ac_loss per correct accent_ru',
#        'val_ac_loss per correct accent_de_ni', 'Precision_Standard',
#        'events.out.tfevents.1663140137.kyoto.604229.0', 'Recall_Standard',
#        'No. of times each accent was predicted_Standard', 'F1-score_Standard',
#        'F1-score_Accented', 'No. of times each accent was predicted_Accented',
#        'val_ac_loss per correct accent_at',
#        'val_ac_loss per correct accent_de',
#        'val_ac_loss per correct accent_avg (unweighted)', 'Recall_Accented',
#        'val_ac_loss per correct accent_gb',
#        'No. of times each accent was predicted when the correct accent is Accented_Standard',
# ...

# %%
plt.plot(df_train["AC Loss"])

# %%
for col in df_val.columns:
    if "val_ac_loss" in col:
        plt.plot(df_val[col], label=col)
plt.legend()

# %%
for col in df_val.columns:
    if "F1-score" in col:
        plt.plot(df_val[col], label=col)
plt.legend()

# %%
for col in df_val.columns:
    if col in ["Precision_avg", "Recall_avg"]:
        plt.plot(df_val[col], label=col)
plt.legend()
